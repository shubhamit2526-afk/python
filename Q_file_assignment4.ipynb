# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhamit2526-afk/python/blob/main/Q_file_assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Write a Python program to read an entire text file.

try:
    print(open("file.txt").read())
except FileNotFoundError:
    print("File not found")

# 2. Write a Python program to read first n lines of a file.

def read_n_lines(n):
    try:
        f = open("file.txt", "r")
        for i in range(n):
            print(f.readline(), end="")
        f.close()
    except FileNotFoundError:
        print("File not found")

read_n_lines(3)

# 3. Write a Python program to append text to a file and display the text.


f = open("file.txt", "a")
f.write("\nNew text added")
f.close()


f = open("file.txt", "r")
print(f.read())
f.close()

# 4. Write a Python program to read last n lines of a file.

def read_last_n_lines(n):
    f = open("file.txt", "r")
    lines = f.readlines()
    f.close()

    for line in lines[-n:]:
        print(line, end="")

read_last_n_lines(3)

# 5. Write a Python program to read a file line by line and store it into a list.

f = open("file.txt", "r")
lines = f.readlines()
f.close()

print(lines)
# Out:
# File not found
# File not found
#
# New text added
#
# New text added['\n', 'New text added']

# %%
# 6. Write a Python program to read a file line by line store it into a variable.

f = open("file.txt", "r")
data = f.read()
f.close()

print(data)

# 7. Write a python program to find the longest words.

words = input("Enter words: ").split()

longest = max(words, key=len)

print("Longest word:", longest)

# 8. Write a Python program to count the number of lines in a text file.

f = open("file.txt", "r")
count = len(f.readlines())
f.close()

print("Number of lines:", count)

# 9. Write a Python program to count the frequency of words in a file.

f = open("file.txt", "r")
text = f.read()
f.close()

words = text.split()

freq = {}

for w in words:
    freq[w] = freq.get(w, 0) + 1

print(freq)

# 10. Write a Python program to get the file size of a plain file.

import os

size = os.path.getsize("file.txt")
print("File size:", size)
# Out:
# New text added

# %%
# 11. Write a Python program to write a list to a file.

data = ["Python", "Java", "C++"]

f = open("file.txt", "w")

for item in data:
    f.write(item + "\n")

f.close()

# 12. Write a Python program to copy the contents of a file to another file .

f1 = open("file.txt", "r")
data = f1.read()
f1.close()

f2 = open("copy.txt", "w")
f2.write(data)
f2.close()

print("File copied successfully")

# 13. Write a Python program to read a random line from a file.

import random

f = open("file.txt", "r")
lines = f.readlines()
f.close()

print(random.choice(lines))

# 14. Write a Python program to assess if a file is closed or not.

f = open("file.txt", "r")

print("Is file closed?", f.closed)

f.close()

print("Is file closed?", f.closed)




# 15.Write a Python program that takes a text file as input and returns the number of words of a given text file.

f = open("file.txt", "r")
text = f.read()
f.close()

words = text.split()

print("Number of words:", len(words))
